# %% [markdown]
# # 01. Importing Libraries and dataframes

# %%
# Importing libraries

import pandas as pd
import numpy as np
import os

# %%
path = r'/Users/zoipisourika/Desktop/Career Foundry/Data Immersion/Achievement 4/Instacart Basket Analysis/02 Data'

# %%
df_prods = pd.read_csv(os.path.join(path, 'Prepared Data', 'product_checked.csv'), index_col = False)

# %%
df_ords_prods_combined = pd.read_pickle(os.path.join(path, 'Prepared Data', 'orders_products_combined.pkl'))

# %%
# Checking dataframes

df_prods
# Out:
#        Unnamed: 0  product_id  \
# 0               0           1
# 1               1           2
# 2               2           3
# 3               3           4
# 4               4           5
# ...           ...         ...
# 49667       49688       49684
# 49668       49689       49685
# 49669       49690       49686
# 49670       49691       49687
# 49671       49692       49688
#
#                                             product_name  aisle_id  \
# 0                             Chocolate Sandwich Cookies        61
# 1                                       All-Seasons Salt       104
# 2                   Robust Golden Unsweetened Oolong Tea        94
# 3      Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4                              Green Chile Anytime Sauce         5
# ...                                                  ...       ...
# 49667          Vodka, Triple Distilled, Twist of Vanilla       124
# ...

# %%
# Checking dataframes

df_ords_prods_combined
# Out:
#           order_id  user_id  order_number  orders_day_of_the_week  \
# 0          2539329        1             1                       2
# 1          2539329        1             1                       2
# 2          2539329        1             1                       2
# 3          2539329        1             1                       2
# 4          2539329        1             1                       2
# ...            ...      ...           ...                     ...
# 32434484   2977660   206209            13                       1
# 32434485   2977660   206209            13                       1
# 32434486   2977660   206209            13                       1
# 32434487   2977660   206209            13                       1
# 32434488   2977660   206209            13                       1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     7.0         196
# ...

# %%
# Dropping Unnamed column from df_prods

df_prods = df_prods.drop(columns = ['Unnamed: 0'])

# %%
# Check df_prods

df_prods
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49667       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49668       49685                 En Croute Roast Hazelnut Cranberry
# 49669       49686                                   Artisan Baguette
# 49670       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49671       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %% [markdown]
# # 02. Combining dataframes

# %% [markdown]
# ### 02.1 Determining the best way to combine the above dataframes

# %% [markdown]
# A left join, using the df_ords_prods_combined as the left data set is the best way to keep the orders information and add to them the product information from the df_prods (which will be the right data set).

# %%
df_ords_prods_merged = df_ords_prods_combined.merge(df_prods, on = 'product_id', how = 'left', indicator = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/xq/3wlvk7756nj3ym71_4x3pj1r0000gn/T/ipykernel_2540/1155854338.py in <module>
# ----> 1 df_ords_prods_merged = df_ords_prods_combined.merge(df_prods, on = 'product_id', how = 'left', indicator = True)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9352         from pandas.core.reshape.merge import merge
#    9353
# -> 9354         return merge(
#    9355             self,
#    9356             right,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     120         validate=validate,
#     121     )
# ...

# %% [markdown]
# I researched the error above and realised it's because I saved the 'orders_products_combined.pkl' with the '_merge' column. So, I will drop this below.

# %%
df_ords_prods_combined = df_ords_prods_combined.drop(columns = '_merge')

# %%
# Checking the output from the above action

df_ords_prods_combined
# Out:
#           order_id  user_id  order_number  orders_day_of_the_week  \
# 0          2539329        1             1                       2
# 1          2539329        1             1                       2
# 2          2539329        1             1                       2
# 3          2539329        1             1                       2
# 4          2539329        1             1                       2
# ...            ...      ...           ...                     ...
# 32434484   2977660   206209            13                       1
# 32434485   2977660   206209            13                       1
# 32434486   2977660   206209            13                       1
# 32434487   2977660   206209            13                       1
# 32434488   2977660   206209            13                       1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     7.0         196
# ...

# %% [markdown]
# Now, I will try merging again.

# %%
df_ords_prods_merged = df_ords_prods_combined.merge(df_prods, on = 'product_id', how = 'left', indicator = True)

# %%
df_ords_prods_merged
# Out:
#           order_id  user_id  order_number  orders_day_of_the_week  \
# 0          2539329        1             1                       2
# 1          2539329        1             1                       2
# 2          2539329        1             1                       2
# 3          2539329        1             1                       2
# 4          2539329        1             1                       2
# ...            ...      ...           ...                     ...
# 32435054   2977660   206209            13                       1
# 32435055   2977660   206209            13                       1
# 32435056   2977660   206209            13                       1
# 32435057   2977660   206209            13                       1
# 32435058   2977660   206209            13                       1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     7.0         196
# ...

# %%
# Confirm the results of the merge using the merge flag.

df_ords_prods_merged['_merge'].value_counts()
# Out:
# both          32404859
# left_only        30200
# right_only           0
# Name: _merge, dtype: int64

# %%
df_ords_prods_merged_inner = df_ords_prods_combined.merge(df_prods, on = 'product_id', how = 'inner', indicator = True)

# %%
df_ords_prods_merged_inner
# Out:
#           order_id  user_id  order_number  orders_day_of_the_week  \
# 0          2539329        1             1                       2
# 1          2398795        1             2                       3
# 2           473747        1             3                       3
# 3          2254736        1             4                       4
# 4           431534        1             5                       4
# ...            ...      ...           ...                     ...
# 32404854   1320836   202557            17                       2
# 32404855     31526   202557            18                       5
# 32404856    758936   203436             1                       2
# 32404857   2745165   203436             2                       3
# 32404858   3093936   205420             1                       4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     7.0         196
# ...

# %%
df_ords_prods_merged_inner.to_pickle(os.path.join(path, 'Prepared Data', 'orders_products_merged.pkl'))
