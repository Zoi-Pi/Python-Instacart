# %% [markdown]
# # 1. Importing Libraries & Dataframes

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
path = r'/Users/zoipisourika/Desktop/Career Foundry/Data Immersion/Achievement 4/Instacart Basket Analysis'

# %%
# Import customer dataset

df = pd.read_csv(os.path.join(path, "02 Data", "customers.csv"))

# %%
# Import orders_products_merged data set from previous exercise

ords_prods = pd.read_pickle(os.path.join(path, "02 Data", "Prepared Data", "orders_products_with_flags.pkl"))

# %% [markdown]
# # 2. Data Wrangling & Consistency Checks

# %% [markdown]
# ## 2.1 Customer Dataframe

# %%
# Check my customer dataframe output

df
# Out:
#         user_id First Name    Surnam  Gender           STATE  Age date_joined  \
# 0         26711    Deborah  Esquivel  Female        Missouri   48    1/1/2017
# 1         33890   Patricia      Hart  Female      New Mexico   36    1/1/2017
# 2         65803    Kenneth    Farley    Male           Idaho   35    1/1/2017
# 3        125935   Michelle     Hicks  Female            Iowa   40    1/1/2017
# 4        130797        Ann   Gilmore  Female        Maryland   26    1/1/2017
# ...         ...        ...       ...     ...             ...  ...         ...
# 206204   168073       Lisa      Case  Female  North Carolina   44    4/1/2020
# 206205    49635     Jeremy   Robbins    Male          Hawaii   62    4/1/2020
# 206206   135902      Doris  Richmond  Female        Missouri   66    4/1/2020
# 206207    81095       Rose   Rollins  Female      California   27    4/1/2020
# 206208    80148    Cynthia     Noble  Female        New York   55    4/1/2020
#
# ...

# %%
# Drop name columns that don't add anything to analysis

df = df.drop(columns = ['First Name', 'Surnam'])

# %%
# Check df output

df
# Out:
#         user_id  Gender           STATE  Age date_joined  n_dependants  \
# 0         26711  Female        Missouri   48    1/1/2017             3
# 1         33890  Female      New Mexico   36    1/1/2017             0
# 2         65803    Male           Idaho   35    1/1/2017             2
# 3        125935  Female            Iowa   40    1/1/2017             0
# 4        130797  Female        Maryland   26    1/1/2017             1
# ...         ...     ...             ...  ...         ...           ...
# 206204   168073  Female  North Carolina   44    4/1/2020             1
# 206205    49635    Male          Hawaii   62    4/1/2020             3
# 206206   135902  Female        Missouri   66    4/1/2020             2
# 206207    81095  Female      California   27    4/1/2020             1
# 206208    80148  Female        New York   55    4/1/2020             1
#
#        fam_status  income
# 0         married  165665
# 1          single   59285
# 2         married   99568
# ...

# %%
# Rename columns for spelling consistency

df.rename(columns = {'Gender' : 'gender'}, inplace = True)
df.rename(columns = {'STATE' : 'state'}, inplace = True)
df.rename(columns = {'Age' : 'age'}, inplace = True)

# %%
# Check df output
df
# Out:
#         user_id  gender           state  age date_joined  n_dependants  \
# 0         26711  Female        Missouri   48    1/1/2017             3
# 1         33890  Female      New Mexico   36    1/1/2017             0
# 2         65803    Male           Idaho   35    1/1/2017             2
# 3        125935  Female            Iowa   40    1/1/2017             0
# 4        130797  Female        Maryland   26    1/1/2017             1
# ...         ...     ...             ...  ...         ...           ...
# 206204   168073  Female  North Carolina   44    4/1/2020             1
# 206205    49635    Male          Hawaii   62    4/1/2020             3
# 206206   135902  Female        Missouri   66    4/1/2020             2
# 206207    81095  Female      California   27    4/1/2020             1
# 206208    80148  Female        New York   55    4/1/2020             1
#
#        fam_status  income
# 0         married  165665
# 1          single   59285
# 2         married   99568
# ...

# %%
# Find missing values

df.isnull().sum()
# Out:
# user_id         0
# gender          0
# state           0
# age             0
# date_joined     0
# n_dependants    0
# fam_status      0
# income          0
# dtype: int64

# %% [markdown]
# No missing values found.

# %%
# Find duplicates

df_dups = df[df.duplicated()]
df_dups
# Out:
# Empty DataFrame
# Columns: [user_id, gender, state, age, date_joined, n_dependants, fam_status, income]
# Index: []

# %% [markdown]
# No duplicated values found.

# %%
# Check for mixed-type data

for col in df.columns.tolist():
  weird = (df[[col]].applymap(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df[weird]) > 0:
    print (col)

# %% [markdown]
# No mixed-type data found.

# %%
# Check data types for df

df.dtypes
# Out:
# user_id          int64
# gender          object
# state           object
# age              int64
# date_joined     object
# n_dependants     int64
# fam_status      object
# income           int64
# dtype: object

# %%
# Check data types for ords_prods

ords_prods.dtypes
# Out:
# order_id                    int64
# user_id                     int64
# order_number                int64
# orders_day_of_the_week      int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# product_id                  int64
# add_to_cart_order           int64
# reordered                   int64
# product_name               object
# aisle_id                    int64
# department_id               int64
# prices                    float64
# price_range_loc            object
# busiest_day                object
# busiest_days               object
# busiest_period_of_day      object
# max_order                   int64
# Loyalty_flag               object
# average_spend_user        float64
# Spending_flag              object
# median_order_freq_user    float64
# Order_frequency_flag       object
# dtype: object

# %% [markdown]
# # 3. Combining dataframes

# %%
# Test merge without overwriting or creating new dataframe

pd.merge(df, ords_prods, on = ['user_id'], indicator = True)
# Out:
#           user_id  gender     state  age date_joined  n_dependants fam_status  \
# 0           26711  Female  Missouri   48    1/1/2017             3    married
# 1           26711  Female  Missouri   48    1/1/2017             3    married
# 2           26711  Female  Missouri   48    1/1/2017             3    married
# 3           26711  Female  Missouri   48    1/1/2017             3    married
# 4           26711  Female  Missouri   48    1/1/2017             3    married
# ...           ...     ...       ...  ...         ...           ...        ...
# 32404854    80148  Female  New York   55    4/1/2020             1    married
# 32404855    80148  Female  New York   55    4/1/2020             1    married
# 32404856    80148  Female  New York   55    4/1/2020             1    married
# 32404857    80148  Female  New York   55    4/1/2020             1    married
# 32404858    80148  Female  New York   55    4/1/2020             1    married
#
# ...

# %%
# Merge dataframes 

orders_products_customers = ords_prods.merge(df, on = ['user_id'], indicator = True)

# %%
# Export merged dataframe

orders_products_customers.to_pickle(os.path.join(path, "02 Data", "Prepared Data", "orders_products_customers.pkl"))
